# %% [markdown]
# # 1.0) A Questão de Negócio
#
#   1.1) Qual a minha meta?
#
#   Minha meta com esse projeto é maximizar os ganhos da Roof Imoveis indicando os 5 melhores e piores imóveis para se investir com Dataset apresentado pela contratante.
#
#   1.2) Como posso chegar?
#
#   Primeiramente precisamos entender o que é realmente relevante na escolha de um imóvel promissor, ja tendo isso em mente iremos tratar o dataset com foco nos dados que são relevantes. Com o dataset tratado começamos a gerar os insights e ver quais são as principais ligações que devemos fazer para poder ter extrair todas informações necessárias para tomarmos a melhor escolha para a Roof Imóveis.

# %% [markdown]
# # 2.0) O entendimento do negocio:
#
#   2.1) Quais dados eu tenho disponível:
#
#   Tenho a data de venda, preço do venda, número de cômodos especificados, Tamanho da casa e terreno, número de andares, se está na frente da praia ou não, detalhes tecnicos como degradação da casa, qualidade do material utilizado na construção e até mesmo a vista. Também é apresentado as datas de contrução, de restauração e a localização.
#
#   2.2) Eles são relevantes para o problema?
#
#   A primeiro princípio podemos descartar um dado subjetivo que é a beleza da vista, esse dado é muito pessoal, acredito que a data de construção somente é relevante em imóveis que não possuíram nenhum tipo de restauração, para sermos objetivos também acredito que a qualidade do material utilizado não vai precisar ser mensurado, ja que o valor de venda é um agregado dessas qualidades com imóvel.
#
#   2.3) Eles me trazem uma solução direta?
#
#   Na verdade não, são muitas variáveis que podem alterar a valorização do imóvel com o tempo, então teremos que pensar muito bem nas ligações de dados que iremos fazer para podermos ser acertivos na recomendação do investimento.
#
#   2.4) Qual o meu setor e range de negocio?
#
#   O setor de atuação é a venda de imóveis.

# %% [markdown]
# # 3.0) Coleta de dados:
#
#   3.1) Os dados fazem sentido para o projeto
#
#   Sim, são dados relevantes para podermos entender quais são os principais fatores para valorização de imóveis, os principais dados são o preço da venda, localidade e data de venda, com isso podemos analisar a tendendia de um imóvel em uma determinada localidade para ver se ele valorizou ou desvalorizou com o tempo, com isso conseguimos repetir esse padrão para imóveis da mesma região, dependendo de condições do imóvel, preço metro quadrado e etc.
#
#   3.2) Estão no formato que gostaria?
#
#   Sim, como os dados estão em csv isso falicita bastante todo o processo de tratamento de dados, além de estarem bem organizados de certa forma.
#
#   3.3) O que mais consigo entender através desses dados?
#
#   Conseguimos entender quais fatores predominantes para a valorização de um imóvel, qual a tendencia de tempo para uma pesso optar por restaurar o seu imóvel, também conseguimos através desse dataset a preferêmcia do publico pelo formato da casa, se ela é sobradoou não, se tem muitos comodos separados e como o número de banheiros influência nessa decisão.

# %% [markdown]
# # 4.0) Limpeza de dados
#
#   4.1) Removendo dados outliers e valores ausentes.
#
#   Primeiro arrumei o dataframe utilizando a planilha google, assim consegui que todas as strings que nomeavam cada coluna pudesse estar realmente no topo da tabela. link para tabela usada: https://docs.google.com/spreadsheets/d/1-Sj-yjWQF6IL-uPh2mxM7Pupz16vpttaAHdq6xtq_9o/edit?usp=sharing

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
data = pd.read_csv('kc_house_data1.csv')
data.drop(['waterfront','view','sqft_above','sqft_basement','yr_built','yr_renovated','sqft_living15','sqft_lot15'], inplace=True, axis=1)
data
# Out:
#                id             date          price   bedrooms  bathrooms  \
# 0      9900000190  20141030T000000   $ 268,950.00          3       1.00
# 1      9895000040  20140703T000000   $ 399,900.00          2       1.75
# 2      9842300540  20140624T000000   $ 339,000.00          3       1.00
# 3      9842300485  20150311T000000   $ 380,000.00          2       1.00
# 4      9842300095  20140725T000000   $ 365,000.00          5       2.00
# ...           ...              ...             ...       ...        ...
# 21608     2800031  20150401T000000   $ 235,000.00          3       1.00
# 21609     1200021  20140811T000000   $ 400,000.00          3       1.00
# 21610     1200019  20140508T000000   $ 647,500.00          4       1.75
# 21611     1000102  20140916T000000   $ 280,000.00          6       3.00
# 21612     1000102  20150422T000000   $ 300,000.00          6       3.00
#
#        sqft_living  sqft_lot  floors  condition  grade  zipcode      lat  \
# 0             1320      8100     1.0          3      6    98166  47.4697
# 1             1410      1005     1.5          3      9    98027  47.5446
# 2             1100      4128     1.0          4      7    98126  47.5296
# 3             1040      7372     1.0          5      7    98126  47.5285
# 4             1600      4168     1.5          3      7    98126  47.5297
# ...            ...       ...     ...        ...    ...      ...      ...
# 21608         1430      7599     1.5          4      6    98168  47.4783
# 21609         1460     43000     1.0          3      7    98166  47.4434
# 21610         2060     26036     1.0          4      8    98166  47.4444
# 21611         2400      9373     2.0          3      7    98002  47.3262
# 21612         2400      9373     2.0          3      7    98002  47.3262
#
#           long
# 0     -122.351
# 1     -122.018
# 2     -122.379
# 3     -122.378
# 4     -122.381
# ...        ...
# 21608 -122.265
# 21609 -122.347
# 21610 -122.351
# 21611 -122.214
# 21612 -122.214
#
# [21613 rows x 13 columns]

# %% [markdown]
# O objetivo dessa limpeza de colunas é diminuir a quantidade de dados que não serâo relevantes para nossa análise ou são muito imprecisos.
#
# Não vemos de primeiro momento nenhuma relação desses dados com o valor do imóvel.

# %%
data[data.columns[2]] = data[data.columns[2]].replace('[\$,]', '', regex=True).astype(float)
data['date'] = data['date'].replace('T000000', '', regex=True)
data[data.columns[2:10]] = data[data.columns[2:10]].astype('int')
data
# Out:
#                id      date   price   bedrooms  bathrooms  sqft_living  \
# 0      9900000190  20141030   268950         3          1         1320
# 1      9895000040  20140703   399900         2          1         1410
# 2      9842300540  20140624   339000         3          1         1100
# 3      9842300485  20150311   380000         2          1         1040
# 4      9842300095  20140725   365000         5          2         1600
# ...           ...       ...      ...       ...        ...          ...
# 21608     2800031  20150401   235000         3          1         1430
# 21609     1200021  20140811   400000         3          1         1460
# 21610     1200019  20140508   647500         4          1         2060
# 21611     1000102  20140916   280000         6          3         2400
# 21612     1000102  20150422   300000         6          3         2400
#
#        sqft_lot  floors  condition  grade  zipcode      lat     long
# 0          8100       1          3      6    98166  47.4697 -122.351
# 1          1005       1          3      9    98027  47.5446 -122.018
# 2          4128       1          4      7    98126  47.5296 -122.379
# 3          7372       1          5      7    98126  47.5285 -122.378
# 4          4168       1          3      7    98126  47.5297 -122.381
# ...         ...     ...        ...    ...      ...      ...      ...
# 21608      7599       1          4      6    98168  47.4783 -122.265
# 21609     43000       1          3      7    98166  47.4434 -122.347
# 21610     26036       1          4      8    98166  47.4444 -122.351
# 21611      9373       2          3      7    98002  47.3262 -122.214
# 21612      9373       2          3      7    98002  47.3262 -122.214
#
# [21613 rows x 13 columns]

# %%
data = data.dropna(axis = 0, how ='any')
data
# Out:
#                id      date   price   bedrooms  bathrooms  sqft_living  \
# 0      9900000190  20141030   268950         3          1         1320
# 1      9895000040  20140703   399900         2          1         1410
# 2      9842300540  20140624   339000         3          1         1100
# 3      9842300485  20150311   380000         2          1         1040
# 4      9842300095  20140725   365000         5          2         1600
# ...           ...       ...      ...       ...        ...          ...
# 21608     2800031  20150401   235000         3          1         1430
# 21609     1200021  20140811   400000         3          1         1460
# 21610     1200019  20140508   647500         4          1         2060
# 21611     1000102  20140916   280000         6          3         2400
# 21612     1000102  20150422   300000         6          3         2400
#
#        sqft_lot  floors  condition  grade  zipcode      lat     long
# 0          8100       1          3      6    98166  47.4697 -122.351
# 1          1005       1          3      9    98027  47.5446 -122.018
# 2          4128       1          4      7    98126  47.5296 -122.379
# 3          7372       1          5      7    98126  47.5285 -122.378
# 4          4168       1          3      7    98126  47.5297 -122.381
# ...         ...     ...        ...    ...      ...      ...      ...
# 21608      7599       1          4      6    98168  47.4783 -122.265
# 21609     43000       1          3      7    98166  47.4434 -122.347
# 21610     26036       1          4      8    98166  47.4444 -122.351
# 21611      9373       2          3      7    98002  47.3262 -122.214
# 21612      9373       2          3      7    98002  47.3262 -122.214
#
# [21613 rows x 13 columns]

# %% [markdown]
# Dessa forma garantimos que não tem nenhum valor nulo dentro desse data set.

# %% [markdown]
# # 5.0)Exploração de dados
#
# ### 5.1) Visualização dos dados

# %%
apt_vendidos=data[data.groupby('id')[data.columns[2]].transform('nunique') > 1]
apt_vendidos
apt_vendidos[apt_vendidos.columns[0]] = apt_vendidos[apt_vendidos.columns[0]]/10000000
apt_vendidos
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#                id      date   price   bedrooms  bathrooms  sqft_living  \
# 30     983.420089  20140717   360000         4          2         2080
# 31     983.420089  20150420   550000         4          2         2080
# 37     983.420031  20140716   350000         3          1         1790
# 38     983.420031  20150210   615000         3          1         1790
# 124    982.820046  20140627   260000         2          1          700
# ...           ...       ...      ...       ...        ...          ...
# 21438   10.920039  20141020   250000         3          1         1480
# 21600    0.720018  20141016   150000         2          1          840
# 21601    0.720018  20150424   175000         2          1          840
# 21611    0.100010  20140916   280000         6          3         2400
# 21612    0.100010  20150422   300000         6          3         2400
#
#        sqft_lot  floors  condition  grade  zipcode      lat     long
# 30         4080       1          5      7    98144  47.5720 -122.290
# 31         4080       1          5      7    98144  47.5720 -122.290
# 37         3876       1          5      7    98144  47.5750 -122.288
# 38         3876       1          5      7    98144  47.5750 -122.288
# 124        4800       1          3      7    98122  47.6147 -122.300
# ...         ...     ...        ...    ...      ...      ...      ...
# 21438      3900       1          4      7    98023  47.2977 -122.367
# 21600     12750       1          3      6    98055  47.4840 -122.211
# 21601     12750       1          3      6    98055  47.4840 -122.211
# 21611      9373       2          3      7    98002  47.3262 -122.214
# 21612      9373       2          3      7    98002  47.3262 -122.214
#
# [347 rows x 13 columns]

# %% [markdown]
# Se nós analisarmos os apt que ja foram vendidos a
# gente consegue achar um padrão para poder analisar o que é relevante para ele ter uma valorização ou uma desvalorização.

# %%
apt_vendidos['diff'] = apt_vendidos.groupby('id')[apt_vendidos.columns[2]].shift(-1).sub(apt_vendidos[apt_vendidos.columns[2]])
apt_vendidos
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                id      date   price   bedrooms  bathrooms  sqft_living  \
# 30     983.420089  20140717   360000         4          2         2080
# 31     983.420089  20150420   550000         4          2         2080
# 37     983.420031  20140716   350000         3          1         1790
# 38     983.420031  20150210   615000         3          1         1790
# 124    982.820046  20140627   260000         2          1          700
# ...           ...       ...      ...       ...        ...          ...
# 21438   10.920039  20141020   250000         3          1         1480
# 21600    0.720018  20141016   150000         2          1          840
# 21601    0.720018  20150424   175000         2          1          840
# 21611    0.100010  20140916   280000         6          3         2400
# 21612    0.100010  20150422   300000         6          3         2400
#
#        sqft_lot  floors  condition  grade  zipcode      lat     long      diff
# 30         4080       1          5      7    98144  47.5720 -122.290  190000.0
# 31         4080       1          5      7    98144  47.5720 -122.290       NaN
# 37         3876       1          5      7    98144  47.5750 -122.288  265000.0
# 38         3876       1          5      7    98144  47.5750 -122.288       NaN
# 124        4800       1          3      7    98122  47.6147 -122.300  170000.0
# ...         ...     ...        ...    ...      ...      ...      ...       ...
# 21438      3900       1          4      7    98023  47.2977 -122.367       NaN
# 21600     12750       1          3      6    98055  47.4840 -122.211   25000.0
# 21601     12750       1          3      6    98055  47.4840 -122.211       NaN
# 21611      9373       2          3      7    98002  47.3262 -122.214   20000.0
# 21612      9373       2          3      7    98002  47.3262 -122.214       NaN
#
# [347 rows x 14 columns]

# %% [markdown]
# Com esse código conseguimos ver a diferença de valor de revenda e ver qual o padrão estabelecido.

# %%
import plotly.express as px
fig = px.scatter(apt_vendidos, x="id", y="diff"))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="a950d8d2-695f-4c05-b5f4-00ab9d962038" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a950d8d2-695f-4c05-b5f4-00ab9d962038")) {                    Plotly.newPlot(                        "a950d8d2-695f-4c05-b5f4-00ab9d962038",                        [{"hovertemplate":"id=%{x}<br>diff=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[983.4200885,983.4200885,983.4200305,983.4200305,982.820046,982.820046,980.900002,980.900002,940.711071,940.711071,935.33006,935.33006,925.0900104,925.0900104,923.850004,923.850004,922.2400605,922.2400605,921.150062,921.150062,913.610313,913.610313,894.510032,894.510032,891.050015,891.050015,883.290078,883.290078,882.090338,882.090338,880.781089,880.781089,868.22624,868.22624,865.151038,865.151038,865.140275,865.140275,864.553001,864.553001,856.486027,856.486027,816.102006,816.102006,812.9700644,812.9700644,812.1100395,812.1100395,810.300011,810.300011,806.290007,806.290007,798.30002,798.30002,797.7201065,797.7201065,797.200001,797.200001,796.150001,796.150001,789.9800045,789.9800045,789.380565,789.380565,788.800039,788.800039,785.64003,785.64003,785.640024,785.640024,785.342011,785.342011,785.340025,785.340025,770.196099,770.196099,765.700054,765.700054,752.440025,752.440025,752.0000695,752.0000695,752.000052,752.000052,750.402131,750.402131,740.9700215,740.9700215,738.7500235,738.7500235,723.04004,723.04004,722.7800055,722.7800055,716.700004,716.700004,712.930454,712.930454,679.120012,679.120012,675.1300375,675.1300375,666.902029,666.902029,663.2900574,663.2900574,662.3400187,662.3400187,638.150017,638.150017,630.0000226,630.0000226,614.300002,614.300002,614.110032,614.110032,611.750182,611.750182,602.1501535,602.1501535,602.150097,602.150097,553.610002,553.610002,543.0300171,543.0300171,541.760013,541.760013,533.220053,533.220053,528.2200015,528.2200015,524.980144,524.980144,513.200014,513.200014,512.700132,512.700132,510.1405604,510.1405604,510.1402435,510.1402435,508.3000375,508.3000375,505.480011,505.480011,444.3800385,444.3800385,443.5000705,443.5000705,436.47006,436.47006,434.500051,434.500051,430.520007,430.520007,430.2201085,430.2201085,422.231001,422.231001,420.4400098,420.4400098,420.2400078,420.2400078,415.4300296,415.4300296,413.94802,413.94802,413.944048,413.944048,413.942059,413.942059,403.100052,403.100052,396.930003,396.930003,393.5900232,393.5900232,390.4100089,390.4100089,388.3800011,388.3800011,373.9500096,373.9500096,363.01207,363.01207,359.8600049,359.8600049,357.840106,357.840106,355.890059,355.890059,352.800004,352.800004,352.306906,352.306906,343.2501415,343.2501415,339.504055,339.504055,333.300245,333.300245,333.2000615,333.2000615,332.3059027,332.3059027,330.300013,330.300013,329.3700496,329.3700496,327.1300955,327.1300955,326.230094,326.230094,318.560004,318.560004,289.2700041,289.2700041,278.746072,278.746072,276.7603612,276.7603612,276.7602141,276.7602141,272.6049071,272.6049071,272.4049222,272.4049222,262.1600015,262.1600015,261.992017,261.992017,256.8300045,256.8300045,256.134002,256.134002,256.0801222,256.0801222,247.338092,247.338092,242.2049104,242.2049104,223.150003,223.150003,222.890027,222.890027,221.22001,221.22001,220.6700215,220.6700215,214.370083,214.370083,204.4500213,204.4500213,202.3049218,202.3049218,201.920022,201.920022,199.52002,199.52002,197.430002,197.430002,195.442017,195.442017,192.2059278,192.2059278,190.160009,190.160009,182.3049202,182.3049202,178.890023,178.890023,178.880063,178.880063,178.1500435,178.1500435,172.180101,172.180101,163.0700361,163.0700361,156.81003,156.81003,154.580029,154.580029,152.4079093,152.4079093,152.3049207,152.3049207,145.010 ...

# %%
prejuizo = apt_vendidos[apt_vendidos['diff'] < 0]
prejuizo
# Out:
#                id      date   price   bedrooms  bathrooms  sqft_living  \
# 2405   868.226240  20140718   430000         2          1         1350
# 6022   716.700004  20140813   740000         4          3         3350
# 10009  413.942059  20140520  1212500         4          3         4560
# 14411  276.760361  20140512   500000         2          2         1290
# 14515  272.604907  20141211   510000         2          1          820
# 14741  261.992017  20141001   772500         4          2         3230
#
#        sqft_lot  floors  condition  grade  zipcode      lat     long     diff
# 2405       4003       1          3      8    98053  47.7176 -122.033 -10050.0
# 6022     199253       2          3     10    98010  47.3602 -121.988 -40000.0
# 10009     16643       1          3     12    98006  47.5521 -122.115 -12500.0
# 14411      1334       3          3      8    98107  47.6719 -122.382 -11000.0
# 14515      4206       1          3      5    98125  47.7076 -122.284 -20050.0
# 14741      4290       2          3      9    98033  47.6874 -122.161  -7500.0

# %% [markdown]
# Podemos notar alguns padrões para o investimento ter prejuízo, sentimos um padrão no bedrooms ou 2 ou 4, também notamos que a condition está todas no valor 3, além disso notamos que pelo menos o tamanho do terreno é pelo menos 3x o tamanho da casa em 4 de 6 imóveis.

# %%
filter_values = np.where((data[data.columns[3]] == 4) & (data[data.columns[8]] == 3) & (data['sqft_lot'] >= (4*data['sqft_living'])))
low5imoveis = data.loc[filter_values]
low5imoveis
# Out:
#                id      date   price   bedrooms  bathrooms  sqft_living  \
# 110    9828202030  20150218   428000         4          2         1300
# 165    9808610410  20140822   640000         4          2         2320
# 166    9808610190  20140509   782000         4          2         2830
# 173    9804500420  20150424   430000         4          2         2470
# 204    9562200090  20140624   925000         4          3         3580
# ...           ...       ...      ...       ...        ...          ...
# 21541    42000245  20140613   171000         4          2         1520
# 21548    40000669  20150319   499950         4          2         2910
# 21581    11520200  20141015   750000         4          2         3020
# 21582    11520030  20140624   640000         4          2         2341
# 21584    11510310  20140905   835000         4          2         3130
#
#        sqft_lot  floors  condition  grade  zipcode      lat     long
# 110        7200       1          3      7    98122  47.6169 -122.294
# 165       11259       2          3      9    98004  47.6443 -122.194
# 166       20345       2          3     10    98004  47.6462 -122.191
# 173       50123       1          3      8    98022  47.2504 -122.000
# 204       35261       1          3     10    98072  47.7577 -122.134
# ...         ...     ...        ...    ...      ...      ...      ...
# 21541     19672       1          3      6    98188  47.4683 -122.281
# 21548     20067       2          3      9    98168  47.4714 -122.273
# 21581     13122       2          3      9    98052  47.6989 -122.111
# 21582      9594       2          3      9    98052  47.6993 -122.115
# 21584     13412       2          3      9    98052  47.6993 -122.102
#
# [1600 rows x 13 columns]

# %%
lucro = apt_vendidos[apt_vendidos['diff'] > 0]
lucro = lucro.sort_values(by="diff",ascending=False)
lucro.head()
# Out:
#                id      date   price   bedrooms  bathrooms  sqft_living  \
# 7757   602.150097  20140528   345000         2          1         1080
# 3523   797.720107  20141104   350000         3          1         1380
# 5243   740.970022  20140606   550000         3          1         1900
# 9317   444.380039  20140818   410000         2          1         1480
# 14953  256.830004  20140625   305000         6          2         1900
#
#        sqft_lot  floors  condition  grade  zipcode      lat     long      diff
# 7757       4000       1          3      7    98117  47.6902 -122.387  529950.0
# 3523       4590       1          2      7    98115  47.6841 -122.293  390000.0
# 5243       5000       1          3      7    98115  47.6779 -122.294  371500.0
# 9317       4080       1          3      7    98117  47.6842 -122.393  368100.0
# 14953      8240       1          2      7    98125  47.7037 -122.296  344950.0

# %% [markdown]
# Nos gráficos acima temos os imóveis que tiveram prejuizo e no outro temos os imóveis que tiveram mais lucro na revenda.
# Notamos que a maior taxa de lucratividade está em imóveis simples, com apenas 1 piso, com apenas 1 banheiro e de 2 a 3 quartos e também vemos que a localidade faz diferença na valorização dos imóveis quando vemos que os 5 imóveis que mais valorizaram tem apenas 3 zipcode.

# %%
filtered_values = np.where((data[data.columns[7]] <= 1) & (data[data.columns[4]] <=1)&(data['bedrooms'] <=3)&(data['bedrooms'] >=2)&(data['zipcode'] == 98117))
top5imoveis = data.loc[filtered_values]
top5imoveis
# Out:
#                id      date   price   bedrooms  bathrooms  sqft_living  \
# 909    9376301591  20150414   580000         3          1         1570
# 911    9376301180  20150408   552500         3          1         1430
# 1258   9268200658  20140604   280000         2          1          960
# 1259   9268200641  20140820   350000         2          1          800
# 1260   9268200600  20140519   413500         2          1          770
# ...           ...       ...      ...       ...        ...          ...
# 21181   225039049  20140908   590000         2          1         1530
# 21182   225039029  20150317   525000         3          1         1940
# 21366   125039025  20140611   530000         3          1         1550
# 21367   125039021  20140924   575000         2          1         1230
# 21445   106000015  20140619   435000         3          1         1310
#
#        sqft_lot  floors  condition  grade  zipcode      lat     long
# 909        2600       1          4      8    98117  47.6867 -122.370
# 911        5000       1          3      7    98117  47.6895 -122.370
# 1258       4920       1          3      6    98117  47.6946 -122.362
# 1259       5040       1          3      6    98117  47.6953 -122.362
# 1260       4000       1          5      5    98117  47.6959 -122.364
# ...         ...     ...        ...    ...      ...      ...      ...
# 21181      6450       1          4      7    98117  47.6833 -122.398
# 21182      5625       1          4      7    98117  47.6818 -122.388
# 21366      3680       1          3      7    98117  47.6817 -122.360
# 21367      2726       1          3      7    98117  47.6815 -122.359
# 21445      8065       1          4      6    98117  47.7010 -122.368
#
# [249 rows x 13 columns]

# %% [markdown]
# Como o zipcode com maior valorização é o 98117, utilizamos ele como um local exemplo de valorização de imóveis.
# Na tabela acima os imóveis tem as características ja citadas no ultimo passo que foi encontrar o padrão das casas com maior lucratividade na revenda.
# No caso para lucrarmos mais, temos que investir mais, portanto podemos ordenar a tabela acima pelo preço e investir nos 5 imóveis mais caros porque provavelmente vamos ter uma lucratividade boa na revenda.

# %% [markdown]
# ### 5.2) Recomendação de investimento

# %%
top5imoveis = top5imoveis.sort_values(by=top5imoveis.columns[2],ascending=False)
recomendação_de_investimento = top5imoveis.head()
recomendação_de_investimento
# Out:
#                id      date   price   bedrooms  bathrooms  sqft_living  \
# 5001   7518508625  20150416   900000         3          1         1560
# 7758   6021500970  20150407   874950         2          1         1080
# 20402   579000096  20141010   780000         3          1         1620
# 9318   4443800385  20150506   778100         2          1         1480
# 4467   7748000020  20140621   750000         3          1         2610
#
#        sqft_lot  floors  condition  grade  zipcode      lat     long
# 5001       3825       1          3      8    98117  47.6803 -122.387
# 7758       4000       1          3      7    98117  47.6902 -122.387
# 20402      7500       1          4      8    98117  47.7014 -122.381
# 9318       4080       1          3      7    98117  47.6842 -122.393
# 4467       5544       1          3      8    98117  47.6840 -122.376

# %% [markdown]
# A tabela acima é minha recomendação de investimento.

# %%
low5imoveis = low5imoveis.sort_values(by=top5imoveis.columns[2],ascending=False)
nao_invista = low5imoveis.head()
nao_invista
# Out:
#                id      date   price   bedrooms  bathrooms  sqft_living  \
# 11100  3835500195  20140618  4489000         4          3         6430
# 13372  3126059023  20150303  3395000         4          3         4730
# 13132  3225069065  20140624  3075000         4          5         4550
# 11770  3625049014  20140829  2950000         4          3         4860
# 5267   7397300220  20140529  2750000         4          3         4430
#
#        sqft_lot  floors  condition  grade  zipcode      lat     long
# 11100     27517       2          3     12    98004  47.6208 -122.219
# 13372     47870       1          3     10    98033  47.6967 -122.216
# 13132     18641       1          3     10    98074  47.6053 -122.077
# 11770     23885       2          3     12    98039  47.6172 -122.230
# 5267      21000       2          3     10    98039  47.6398 -122.237

# %% [markdown]
# Se você investir nesses imóveis acima você tem chances maiores de não ter um lucro alto ou até mesmo ter prejuízo.
